# %% [markdown]
# # Incident Report
#
# ## Table of Contents
# ### Incident Summary _________________________________________________________________________ [Section 1](#Incident-Summary-Section)
# ### Incident Timeline __________________________________________________________________________ [Section 2](#Timeline-Section)
# ### Adversary Actions _________________________________________________________________________ [Section 3](#Adversary-Actions-Section)
# ### Recommendations ________________________________________________________________________ [Section 4](#Recommendations-Section)
# ### Technical Analysis _________________________________________________________________________ [Section 5](#Technical-Analysis-Section)
# >### Console & Log Analysis ______________________________________________________________________ [Section 5.1](#ConsoleLog-Analysis-Section)
# >>### Endpoint Detection and Response __________________________________________________________________ [Section 5.1.1](#EDR-Analysis)
# >>### Security Information & Event Management _________________________________________________________ [Section 5.1.2](#SIEM-Analysis)
# >>### Firewall ______________________________________________________________________________________________ [Section 5.1.3](#Firewall-Analysis)
# >>### Console _____________________________________________________________________________________________ [Section 5.1.4](#Console-Analysis)
# >### Host(s) ________________________________________________________________________________________ [Section 5.2](#Hosts-Section)
# >>### Hostname 1 _________________________________________________________________________________________ [Host 1](#Host-1-Analysis)
# >>### Hostname 2 _________________________________________________________________________________________ [Host 2](#Host-2-Analysis)
# >### Indicators _____________________________________________________________________________________ [Section 5.3](#Indicators-Section)
# >>### Network IOC Data ___________________________________________________________________________________ [Network IOCs](#networking-indicators)
# >>### File(s) Details ________________________________________________________________________________________ [Files(s)](#files)
# >>### User(s) IOCs _________________________________________________________________________________________ [User(s)](#users)
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# ---
# ## Incident Summary Section
#
# [A few paragraphs describing the incident, investigation, and analysis results]
#
# [This is also sometimes referred to as the Executive Summary but that can also be a separate section]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
# ## Timeline Section
#
# [Refer to IncidentTracking.xlsx and the “TIMELINE” here when completed]
#
# [Some options for including the Incident Timeline: Can insert as an image/link, build into a markdown table, or use an addon like Mito to embed]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
# ## Adversary Actions Section
#
# [Include which MITRE TTPs were observed and details of how it matches]
#
# [Tactic Observed]:
# >[Technique Name]: [Correlating Incident details]
#
# [Tactic Observed]:
# >[Technique Name]: [Correlating Incident details]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
# ## Recommendations Section
#
# [List or table the actions needed to address the root cause]
#
# |Priority|Title|Description|
# |--------------|-----------|-----------------|
# |High|title|describe the recommendation or action needed|
# |Medium|title|describe the recommendation or action needed|
# |Low|title|describe the recommendation or action needed|
#
# [Provide alternatives and a why behind the recommendations]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
# ## Technical Analysis Section
#
# [Technical Analysis Summary]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
# ### Console/Log Analysis Section
#
# [Brief summary of scope for this section]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Section Start](#technical-analysis-section)
#
# ---
# ### EDR Analysis
#
# [Include any EDR related analysis]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#consolelog-analysis-section)
#
# ---
# ### SIEM Analysis
#
# [Include any SIEM related analysis]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#consolelog-analysis-section)
#
# ---
# ### Firewall Analysis
#
# [Include any Firewall related analysis]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#consolelog-analysis-section)
#
# ---
# ### Console Analysis
#
# [Include any Console related analysis]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#consolelog-analysis-section)
#
# ---
# ## Host(s) Section
#
# [Brief summary of Hosts involved]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Main Section Start](#technical-analysis-section)
#
# ---
# ### Host 1 Analysis
#
# Artifact
#
# >[Analysis Notes regarding the artifact]
#
# Artifact 2
#
# >[Analysis Notes regarding the artifact]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#hosts-section)
#
# ---
# ### Host 2 Analysis
#
# Artifact
#
# >[Analysis Notes regarding the artifact]
#
# Artifact 2
#
# >[Analysis Notes regarding the artifact]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#hosts-section)
#
# ---
# ## Indicators Section
#
# [Brief summary of IOCs involved]
#
# &nbsp;
#
# &nbsp;
#
# [Back to Main Section Start](#technical-analysis-section)
#
# ---
# ### Networking Indicators
#
# [IP Address/DNS]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#indicators-section)
#
# ---
# ### File(s)
#
# [File Name/Hash]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#indicators-section)
#
# ---
# ### User(s)
#
# [Domain and Username]
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# &nbsp;
#
# [Back to Sub-Section Start](#indicators-section)
#
# ---
#
# &nbsp;
#
# &nbsp;
#
# [Back to Table of Contents](#table-of-contents)
#
# ---
